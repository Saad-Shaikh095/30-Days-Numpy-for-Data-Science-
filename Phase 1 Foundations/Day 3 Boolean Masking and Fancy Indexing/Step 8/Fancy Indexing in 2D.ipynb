# %%
import numpy as np

# %%
matrix = np.array([
    [10, 20],
    [30, 40],
    [50, 60]
])

# %%
matrix
# Out:
# array([[10, 20],
#        [30, 40],
#        [50, 60]])

# %% [markdown]
# # Select row 0 and 2:

# %%
matrix[[0, 2]]
# Out:
# array([[10, 20],
#        [50, 60]])
