# %%
import numpy as np

# %% [markdown]
# ## Random float (0 to 1)

# %%
np.random.rand()
# Out:
# 0.44353351786767725

# %% [markdown]
# ## Random array

# %%
np.random.rand(5)
# Out:
# array([0.76353257, 0.11683944, 0.39524589, 0.99189733, 0.55576097])

# %%
np.random.rand(3, 3)
# Out:
# array([[0.78637913, 0.83107076, 0.64627171],
#        [0.7254732 , 0.68330538, 0.91434679],
#        [0.3212018 , 0.85104557, 0.39581678]])
