# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 6])
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# # Method 1: flatten() (COPY)

# %%
b = a.reshape(2, 3)
flat = b.flatten()

# %% [markdown]
# # Method 2: ravel() (VIEW)

# %%
rav = b.ravel()

# %% [markdown]
# ## 📌 Difference coming next 👇
