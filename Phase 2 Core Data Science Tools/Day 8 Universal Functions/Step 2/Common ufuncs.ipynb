# %%
import numpy as np

# %%
a = np.array([1, 4, 9, 16, 25])

# %% [markdown]
# # Square Root

# %%
np.sqrt(a)
# Out:
# array([1., 2., 3., 4., 5.])

# %% [markdown]
# # Power

# %%
np.power(a, 2)
# Out:
# array([  1,  16,  81, 256, 625])

# %% [markdown]
# # Absolute

# %%
np.abs([-10, 5, -3])
# Out:
# array([10,  5,  3])
