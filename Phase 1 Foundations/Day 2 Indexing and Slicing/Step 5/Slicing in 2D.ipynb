# %%
import numpy as np

# %%
b = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

# %%
b
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
b[0:2, 1:3]
# Out:
# array([[20, 30],
#        [50, 60]])

# %% [markdown]
# # Meaning:
#
# * Rows 0–1
#
# * Columns 1–2
