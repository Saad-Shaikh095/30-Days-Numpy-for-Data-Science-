# %%
import numpy as np

# %%
c = np.array([[1, 2, 3],
              [4, 5, 6]])

c + 10
# Out:
# array([[11, 12, 13],
#        [14, 15, 16]])

# %%
d = np.array([10, 20, 30])

c + d
# Out:
# array([[11, 22, 33],
#        [14, 25, 36]])

# %% [markdown]
# # 📌 Rule:
#
# * Last dimensions must match
#
# * Smaller one stretches
