# %%
import numpy as np

# %% [markdown]
# # Python List

# %%
lst = [10, 20, 30]
lst + 10   # ❌ Error

# %% [markdown]
# # Numpy Array

# %%
arr = np.array([10, 20, 30])
arr + 10   # ✅ Works
# Out:
# array([20, 30, 40])

# %% [markdown]
# # Analogy
#
# ### List: you tell each worker individually
#
# ### NumPy: you announce once on loudspeaker 📢
