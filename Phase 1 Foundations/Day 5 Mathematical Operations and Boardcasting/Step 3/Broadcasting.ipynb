# %%
import numpy as np

# %%
c = np.array([[1, 2, 3],
              [4, 5, 6]])

c + 10
# Out:
# array([[11, 12, 13],
#        [14, 15, 16]])

# %%
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# # 🧠 NumPy thinks:
#
# > “Oh, single value? I’ll apply it everywhere.”
