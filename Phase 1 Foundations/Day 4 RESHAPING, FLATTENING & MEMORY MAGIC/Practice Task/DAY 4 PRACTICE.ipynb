# %% [markdown]
# # Task 1
#
# Create array:
#
# `[1, 2, 3, 4, 5, 6, 7, 8]`
#
#
# * Reshape to 2×4
#
# * Reshape to 4×2

# %% [markdown]
# # Task 2
#
# Flatten a 2D array using:
#
# * `flatten()`
#
# * `ravel()`
#
# Change one element and observe difference.

# %% [markdown]
# # Task 3 (Think Deep 🧠)
#
# Answer:
#
# > Why can reshape cause unexpected bugs in data science code?
