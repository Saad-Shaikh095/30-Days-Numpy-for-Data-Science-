# %%
import numpy as np

# %%
a = np.array([1, 4, 9, 16, 25])

# %%
np.log(a)      # natural log
# Out:
# array([0.        , 1.38629436, 2.19722458, 2.77258872, 3.21887582])

# %%
np.log10(a)    # base 10
# Out:
# array([0.        , 0.60205999, 0.95424251, 1.20411998, 1.39794001])

# %%
np.exp(a)      # e^x
# Out:
# array([2.71828183e+00, 5.45981500e+01, 8.10308393e+03, 8.88611052e+06,
#        7.20048993e+10])

# %% [markdown]
# ## 📌 Used in:
#
# * Feature scaling
#
# * Probability
#
# * Loss functions
