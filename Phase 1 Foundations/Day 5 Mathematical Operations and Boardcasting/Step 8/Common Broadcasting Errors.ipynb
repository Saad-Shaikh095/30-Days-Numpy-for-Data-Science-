# %%
import numpy as np

# %%
a = np.array([10, 20, 30, 40])

# %%
x = np.array([1, 2, 3])
y = np.array([1, 2])

x + y   # ❌ Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1471734924.py in <cell line: 0>()
#       2 y = np.array([1, 2])
#       3
# ----> 4 x + y   # ❌ Error
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)

# %% [markdown]
# # 🧠 Shapes don’t align.
