# %%
import numpy as np

# %%
marks = np.array([45, 60, 72, 88, 35, 90])

passed = marks[marks >= 50]
print(passed)
# Out:
# [60 72 88 90]

# %% [markdown]
# # Give grace marks

# %%
marks[marks < 50] += 5

# %%
marks
# Out:
# array([50, 60, 72, 88, 40, 90])

# %% [markdown]
# # 🧠 Like saying:
#
# > “Everyone below 50, get +5”
