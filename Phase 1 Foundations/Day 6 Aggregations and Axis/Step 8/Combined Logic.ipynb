# %%
import numpy as np

# %%
marks = np.array([
    [70, 80, 90],
    [60, 75, 85],
    [88, 92, 95]
])

# %%
total = np.sum(marks, axis=1)
topper = np.argmax(total)

# %%
topper
# Out:
# np.int64(2)
