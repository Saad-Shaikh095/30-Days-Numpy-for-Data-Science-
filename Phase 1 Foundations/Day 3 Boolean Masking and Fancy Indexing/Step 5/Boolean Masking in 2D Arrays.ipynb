# %%
import numpy as np

# %%
data = np.array([
    [65, 70, 80],
    [90, 85, 88],
    [40, 55, 60]
])

# %%
data
# Out:
# array([[65, 70, 80],
#        [90, 85, 88],
#        [40, 55, 60]])

# %% [markdown]
# # All values > 70

# %%
data[data > 70]
# Out:
# array([80, 90, 85, 88])

# %% [markdown]
# # Students with any subject < 50

# %%
data[data < 50]
# Out:
# array([40])
