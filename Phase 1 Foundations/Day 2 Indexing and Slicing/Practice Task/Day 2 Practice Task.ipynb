# %% [markdown]
# # Task 1
#
# Create this array:
#
# `[5, 10, 15, 20, 25, 30]`
#
#
# *  Print last 3 elements
#
# *  Print alternate elements

# %% [markdown]
# # Task 2
#
# Create a 3×3 matrix:
#
# * Print middle element
#
# * Print first row
#
# * Print last column

# %% [markdown]
# # Task 3 (Think Like Pro 🧠)
#
# Explain in your own words:
#
# > Why do we use `:` in `array[:, 1]?`
