# %%
import numpy as np

# %%
marks = np.array([
    [70, 80, 90],   # Student 1
    [60, 75, 85],   # Student 2
    [88, 92, 95]    # Student 3
])

# %%
marks
# Out:
# array([[70, 80, 90],
#        [60, 75, 85],
#        [88, 92, 95]])

# %% [markdown]
# # Get marks of Student 2

# %%
marks[1]
# Out:
# array([60, 75, 85])

# %% [markdown]
# # Get Math marks of all students (column 0)

# %%
marks[:, 0]
# Out:
# array([70, 60, 88])

# %% [markdown]
# # Get top 2 students, last 2 subjects

# %%
marks[:2, 1:]
# Out:
# array([[80, 90],
#        [75, 85]])
