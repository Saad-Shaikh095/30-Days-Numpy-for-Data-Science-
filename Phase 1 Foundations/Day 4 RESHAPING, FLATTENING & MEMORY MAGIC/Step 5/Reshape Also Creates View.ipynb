# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 6])

# %%
c = a.reshape(2, 3)
c[0, 0] = 999
print(a)
# Out:
# [999   2   3   4   5   6]

# %% [markdown]
# ## 😵‍💫 Original array changed.
#
# ## 📌 Reshape = view (mostly)
