# %%
import numpy as np

a = np.array([10, 25, 40, 55, 70])

# %% [markdown]
# # Now ask:
#
# > “Give me values greater than 30”

# %%
a > 30
# Out:
# array([False, False,  True,  True,  True])

# %% [markdown]
# # This is called a Boolean Mask.
