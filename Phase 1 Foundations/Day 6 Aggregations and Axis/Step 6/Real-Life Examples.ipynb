# %%
import numpy as np

# %%
marks = np.array([
    [70, 80, 90],
    [60, 75, 85],
    [88, 92, 95]
])

# %% [markdown]
# # Highest scorer per subject

# %%
np.max(marks, axis=0)
# Out:
# array([88, 92, 95])

# %% [markdown]
# # Lowest scoring student total

# %%
np.sum(marks, axis=1)
# Out:
# array([240, 220, 275])
