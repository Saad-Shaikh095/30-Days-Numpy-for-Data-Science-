# %%
import numpy as np

# %%
marks = np.array([70, 80, 90])

normalized = (marks - marks.mean()) / marks.std()

# %%
marks
# Out:
# array([70, 80, 90])

# %% [markdown]
# * 🔥 Real data science formula
# * 🔥 No loops
# * 🔥 Clean code
