# %%
import numpy as np

# %%
marks = np.array([
    [70, 80, 90],
    [60, 75, 85],
    [88, 92, 95]
])

# %%
marks
# Out:
# array([[70, 80, 90],
#        [60, 75, 85],
#        [88, 92, 95]])

# %% [markdown]
# Rows → students
#
# Columns → subjects
