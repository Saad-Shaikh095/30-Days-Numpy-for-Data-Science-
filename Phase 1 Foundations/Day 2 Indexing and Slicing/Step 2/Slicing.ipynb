# %%
import numpy as np

# %%
a = np.array([10, 20, 30, 40, 50])
a
# Out:
# array([10, 20, 30, 40, 50])

# %%
a[1:4]      # [20 30 40]
# Out:
# array([20, 30, 40])

# %%
a[:3]       # [10 20 30]
# Out:
# array([10, 20, 30])

# %%
a[::2]      # [10 30 50]
# Out:
# array([10, 30, 50])

# %% [markdown]
# # Analogy:
# Like cutting cake 🎂 — start slice, end slice, step slices.
