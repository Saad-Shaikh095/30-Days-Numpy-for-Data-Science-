# %%
import numpy as np

# %%
data = np.array([10, 20, 30, 40, 50])
np.random.choice(data, size=3, replace=False)
# Out:
# array([10, 40, 50])

# %% [markdown]
# 📌 Used in:
#
# * Train/test split
#
# * Bootstrap sampling
