# %% [markdown]
# # Task 1
# `arr = np.array([12, 45, 67, 23, 90, 34])`
#
#
# * Values > 40
#
# * Values between 20 and 70

# %% [markdown]
# # Task 2
#
# 2D marks array:
#
# * Extract all marks > 80
#
# * Increase marks < 50 by +10

# %% [markdown]
# # Task 3 (Brain Exercise 🧠)
#
# Explain:
#
# > Why NumPy uses & instead of and?
