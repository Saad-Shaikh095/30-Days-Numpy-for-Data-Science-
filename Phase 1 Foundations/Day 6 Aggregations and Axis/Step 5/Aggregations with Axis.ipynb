# %%
import numpy as np

# %%
marks = np.array([
    [70, 80, 90],
    [60, 75, 85],
    [88, 92, 95]
])

# %% [markdown]
# # Average marks per subject

# %%
np.mean(marks, axis=0)
# Out:
# array([72.66666667, 82.33333333, 90.        ])

# %% [markdown]
# # Average marks per student

# %%
np.mean(marks, axis=1)
# Out:
# array([80.        , 73.33333333, 91.66666667])
