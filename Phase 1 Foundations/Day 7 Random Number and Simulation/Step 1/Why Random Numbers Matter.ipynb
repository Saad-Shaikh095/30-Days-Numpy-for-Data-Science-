# %%
import numpy as np

# %% [markdown]
# #Why Random Numbers Matter?

# %% [markdown]
# Used in:
#
# * Machine Learning (train-test split)
#
# * Simulations
#
# * Games
#
# * Stock price modeling 📈
#
# * Monte Carlo methods
