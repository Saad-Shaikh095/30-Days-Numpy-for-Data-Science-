# %% [markdown]
# # Task 1
# `arr = np.array([5, 10, 15, 20])`
#
#
# * Multiply all by 2
#
# * Subtract mean

# %% [markdown]
# # Task 2
#
# 2D array:
#
#
# ```
# data = np.array([[10, 20, 30],
#                  [40, 50, 60]])
#
# ```
#
#
#
#
# Add:
#
# `[1, 2, 3]`
#
#
# (Using broadcasting)

# %% [markdown]
# # Task 3 (Pro Thinking 🧠)
#
# Explain:
#
# > Why broadcasting is faster than loops?
