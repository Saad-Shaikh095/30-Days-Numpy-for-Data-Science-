# %%
import numpy as np

# %%
arr = np.array([10, 20, 30])
arr + 10
# Out:
# array([20, 30, 40])

# %%
print(arr.ndim)   # dimensions
print(arr.shape)  # rows, columns
print(arr.size)   # total elements
print(arr.dtype)  # data type
# Out:
# 1
# (3,)
# 3
# int64

# %% [markdown]
# # Think:
#
# ### **ndim** → how many directions
#
# ### **shape** → structure
#
# ### **dtype** → type of data
