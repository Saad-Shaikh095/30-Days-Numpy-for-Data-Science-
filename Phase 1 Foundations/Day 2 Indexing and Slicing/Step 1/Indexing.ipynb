# %%
import numpy as np

# %% [markdown]
# # 1D Array

# %%
a = np.array([10, 20, 30, 40, 50])
a
# Out:
# array([10, 20, 30, 40, 50])

# %%
a[0]    # 10
# Out:
# np.int64(10)

# %%
a[3]    # 40
# Out:
# np.int64(40)

# %%
a[-1]   # 50 (last element)
# Out:
# np.int64(50)

# %% [markdown]
# # Memory trick
# Positive → from start
#
# Negative → from end
