# %% [markdown]
# # Task 1
#
# Create an array of your last 5 exam marks
# Add +3 grace marks to all.

# %% [markdown]
# # Task 2
#
# Create an array using:
#
# `np.arange(10, 51, 10)`
#
#
# ### Print:
# *   shape
# *   size
# *   dtype

# %% [markdown]
# # Task 3 (Thinking Question 🤯)
#
# Why can NumPy add +10 directly but Python list can’t?
#
# (Answer in your own words)

# %% [markdown]
# # 🔒 Day 1 Checkpoint
#
# Before moving to Day 2, you must be able to explain:
#
#
#
# 1.   What is NumPy?
# 2.   What is an array?
# 3.   Why arrays are faster than lists?
