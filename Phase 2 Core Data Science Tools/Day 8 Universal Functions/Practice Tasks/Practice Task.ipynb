# %% [markdown]
# # Task 1
#
# Given:
#
# `arr = np.array([2, 4, 6, 8, 10])`
#
#
# * Square root
#
# * Log
#
# * Exponential

# %% [markdown]
# # Task 2
#
# Create angles (0–180 step 30):
#
# * Convert to radians
#
# * Find sin values

# %% [markdown]
# # Task 3 (Pro Thinking 🧠)
#
# Explain:
#
# > Why are ufuncs faster than normal Python functions?
