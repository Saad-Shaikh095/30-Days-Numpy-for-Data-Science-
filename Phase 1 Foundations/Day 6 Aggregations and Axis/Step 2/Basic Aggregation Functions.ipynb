# %%
import numpy as np

# %%
a = np.array([10, 20, 30, 40])

# %%
np.sum(a)
# Out:
# np.float64(125.0)

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.std(a)
# Out:
# np.float64(11.180339887498949)

# %%
np.var(a)
# Out:
# np.float64(125.0)
