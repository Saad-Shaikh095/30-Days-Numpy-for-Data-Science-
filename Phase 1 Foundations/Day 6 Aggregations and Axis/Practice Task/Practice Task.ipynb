# %% [markdown]
# # Task 1
#
# 1D array:
#
# * Find sum
#
# * Mean
#
# * Standard deviation

# %% [markdown]
# # Task 2
#
# 2D marks array:
#
# * Average per student
#
# * Average per subject

# %% [markdown]
# # Task 3 (Deep Thinking 🧠)
#
# Explain:
#
# > Why is axis important in data analysis?
