# %%
import numpy as np

# %%
a = np.array([10, 20, 30, 40])

# %% [markdown]
# ### Basic Math

# %%
a + 5
a - 2
a * 3
a / 2
# Out:
# array([ 5., 10., 15., 20.])

# %% [markdown]
# # 📌 Every element is affected.
#
# 🧠 Analogy:
#
# > Like announcing on mic 📢 — everyone follows.
