# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 6])
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# # 1D → 2D

# %%
a.reshape(2, 3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# # 📌 Rule:
#
# > Total elements must match
#
# > (2×3 = 6 ✔️)
