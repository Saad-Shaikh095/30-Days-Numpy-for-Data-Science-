# %%
import numpy as np

# %%
a = np.array([10, 20, 30, 40])
b = np.array([1, 2, 3, 4])

a + b
a * b
# Out:
# array([ 10,  40,  90, 160])

# %% [markdown]
# # 📌 Rule:
#
# Shapes must match (or be broadcastable 👀)
