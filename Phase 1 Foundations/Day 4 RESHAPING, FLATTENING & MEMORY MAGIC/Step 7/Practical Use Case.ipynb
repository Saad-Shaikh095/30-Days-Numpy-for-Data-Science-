# %%
import numpy as np

# %%
X = np.array([1, 2, 3, 4, 5, 6])
X = X.reshape(-1, 1)

# %%
X
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])

# %% [markdown]
# # 📌 Required shape for ML models.
