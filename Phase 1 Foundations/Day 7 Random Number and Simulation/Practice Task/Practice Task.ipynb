# %% [markdown]
# # Task 1
#
# Simulate:
#
# * 50 dice rolls
#
# * Find mean & max

# %% [markdown]
# # Task 2
#
# Generate:
#
# * 100 student marks using normal distribution
#
# * Find average & topper

# %% [markdown]
# # Task 3 (Thinking 🧠)
#
# Explain:
#
# > Why is setting a random seed important in Data Science?
