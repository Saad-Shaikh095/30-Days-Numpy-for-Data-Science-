# %%
import numpy as np

# %%
principal = np.array([1000, 2000, 3000])
rate = 0.05
years = 5

final_amount = principal * np.exp(rate * years)

# %%
final_amount
# Out:
# array([1284.02541669, 2568.05083338, 3852.07625006])
