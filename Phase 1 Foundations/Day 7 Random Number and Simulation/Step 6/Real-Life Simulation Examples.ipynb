# %%
import numpy as np

# %% [markdown]
# ## Exam Marks Simulation

# %%
marks = np.random.normal(70, 10, 100)

# %% [markdown]
# ## Coin Toss

# %%
np.random.choice(['H', 'T'], size=20)
# Out:
# array(['T', 'T', 'H', 'T', 'T', 'H', 'H', 'H', 'T', 'H', 'T', 'T', 'H',
#        'H', 'T', 'H', 'T', 'H', 'H', 'H'], dtype='<U1')
