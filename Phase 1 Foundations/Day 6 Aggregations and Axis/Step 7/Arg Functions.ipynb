# %%
import numpy as np

# %%
a = np.array([10, 20, 30, 40])

# %%
np.argmax(a)
# Out:
# np.int64(0)

# %%
np.argmin(a)
# Out:
# np.int64(0)

# %%
np.argmax(marks, axis=1)
# Out:
# array([2, 2, 2])

# %% [markdown]
# Returns index, not value.
