# %%
import numpy as np

# %%
x = np.array([1, 2, 3, 4])

y = np.sqrt(x) + np.log(x)

# %%
result = []
for i in x:
    result.append(np.sqrt(i))

# %%
np.sqrt(x)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        ])

# %% [markdown]
# ## 📌 ufuncs are:
#
# * Faster
#
# * Cleaner
#
# * CPU optimized
