# %%
import numpy as np

# %%
marks = np.array([45, 60, 72, 88, 35, 90])

passed = marks[marks >= 50]
print(passed)
# Out:
# [60 72 88 90]

# %% [markdown]
# 💡 No loop
#
# 💡 Clean
#
# 💡 Fast
#
# This is **industry-style filtering**.
